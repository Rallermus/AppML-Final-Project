# %%
from data_import import import_flight_data
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_dir = '/Users/rasmus/Desktop/Fysik/AppliedML2026/Final_project_data/data/ML_data/NBI/FDM data'

df = import_flight_data(data_dir=data_dir,limit=1, recursive=True)

# %%
COLUMN_MAP = {
    # time
    "Year": "year",
    "QAR YEAR": "year",
    "Date: Year (Derived)": "year",

    "MONTH": "month",
    "QAR MONTH": "month",
    "Date (month)": "month",

    "DAY": "day",
    "QAR DAY": "day",
    "Date (day)": "day",

    "GMT - Hours (BCD)": "hour",
    "QAR HOUR": "hour",
    "UTC Hours": "hour",

    "GMT - Minutes (BCD)": "minute",
    "QAR MINUTE": "minute",
    "UTC Minutes": "minute",

    "GMT Seconds": "second",
    "QAR SECOND": "second",
    "UTC Seconds": "second",

    # altitude
    "Radio Altitude": "radio_altitude",
    "Radio Height 1": "radio_altitude",

    # vertical acceleration
    "Vertical Acceleration": "vert_acc",
    "Normal acceleration": "vert_acc",
}

# %%
N_arrivals = 1

arrival_data = import_flight_data(data_dir=data_dir, 
    limit=N_arrivals, add_source_file=True)#, usecols=['Time (secs)','MONTH', 'DAY', 'Year', 'GMT - Hours (BCD)', 'GMT - Minutes (BCD)', 'GMT Seconds', 'Vertical Acceleration', 'Radio Altitude'])

#arrival_data.columns.tolist()

# %%
def extract_wind_data(flight_df, offset=10): 
    """
    Extracts wind data from the TWI dataset for a given flight, based on the landing time and an offset for the recording start time.
    Args:
        flight_df (pd.DataFrame): A DataFrame containing data for one flight, including landing time information.
        offset (int): The number of minutes before the landing time to start recording wind data. Default is 10 minutes.
    Returns:
        pd.DataFrame: A DataFrame containing the wind data for the specified time range.
    """

    first = flight_df.iloc[0]

    month = first['month'].astype(int)
    day = first['day'].astype(int)
    if day < 10:
        day_string = '0'+str(day)
    else:
        day_string = str(day)

    year = first['year'].astype(int)
    start_h = first['hour'].astype(int)
    start_m = first['minute'].astype(int)
    start_s = first['second'].astype(int)
    
    start_of_landing_time = pd.Timestamp(year=year,month=month,day=day,hour=start_h,minute=start_m,second=start_s)

    start_of_recording_time = start_of_landing_time - pd.Timedelta(minutes=offset)
    
    if start_of_recording_time.day != start_of_landing_time.day:
        raise ValueError("Start of recording time is on a different day than the landing time. Please adjust the offset or check the flight data.")
    
    date_string = str(year)+'-'+str(month)+'-'+day_string
    file_string = 'TWI-'+date_string+'_UTC_log.csv'

    wind_df = pd.read_csv('/Users/rasmus/Desktop/Fysik/AppliedML2026/Final_project_data/data/ML_data/TWI data/'+file_string, sep=';')

    wind_df['DateTime'] = pd.to_datetime(wind_df['DateTime'], format='%Y-%m-%d %H:%M:%S')

    mask_time = (wind_df['DateTime'] >= start_of_recording_time) & (wind_df['DateTime'] <= start_of_landing_time)

    wind_df = wind_df.loc[mask_time].reset_index(drop=True)
    wind_df['source_file'] = first['source_file']
    return wind_df

extract_wind_data(arrival_data)
# Out:
#                DateTime               PcTime  ArrRwy04  ArrRwy22  DepRwy22  \
# 0   2024-11-28 12:04:29  2024-11-28 10:04:30         2         2         2
# 1   2024-11-28 12:04:35  2024-11-28 10:04:35         2         2         2
# 2   2024-11-28 12:04:38  2024-11-28 10:04:40         2         2         2
# 3   2024-11-28 12:04:44  2024-11-28 10:04:45         2         2         2
# 4   2024-11-28 12:04:50  2024-11-28 10:04:50         2         2         2
# ..                  ...                  ...       ...       ...       ...
# 115 2024-11-28 12:14:05  2024-11-28 10:14:05         2         2         2
# 116 2024-11-28 12:14:05  2024-11-28 10:14:10         2         2         2
# 117 2024-11-28 12:14:14  2024-11-28 10:14:15         2         2         2
# 118 2024-11-28 12:14:20  2024-11-28 10:14:20         2         2         2
# 119 2024-11-28 12:14:23  2024-11-28 10:14:25         2         2         2
#
#      DepRwy04  ArrRwy04DepRwy22  ArrRwy22DepRwy04  W04.VectorMeanWindSpeed  \
# 0           2                 0                 0                 3.446184
# 1           2                 0                 0                 3.477918
# 2           2                 0                 0                 3.500163
# 3           2                 0                 0                 3.582905
# 4           2                 0                 0                 3.604055
# ..        ...               ...               ...                      ...
# 115         2                 0                 0                 5.671798
# 116         2                 0                 0                 5.671798
# 117         2                 0                 0                 5.650666
# 118         2                 0                 0                 5.641713
# 119         2                 0                 0                 5.628313
#
#      W04.VectorMeanWindDirection  ...  W22.ScalarMaxWindSpeed  \
# 0                      65.886639  ...                     9.1
# 1                      66.050344  ...                     9.1
# 2                      66.170129  ...                     9.1
# 3                      66.839029  ...                     9.1
# 4                      67.683592  ...                     9.1
# ..                           ...  ...                     ...
# 115                    57.058410  ...                     9.8
# 116                    57.058410  ...                     9.8
# 117                    58.035348  ...                     9.8
# 118                    58.698637  ...                     9.8
# 119                    59.306211  ...                     9.8
#
#      W22.ScalarMaxWindAtDirection  W22.ScalarMeanWindSpeed  \
# 0                              36                 7.655263
# 1                              36                 7.613158
# 2                              36                 7.584211
# 3                              36                 7.544737
# 4                              36                 7.636842
# ..                            ...                      ...
# 115                            48                 7.655263
# 116                            48                 7.655263
# 117                            48                 7.697368
# 118                            48                 7.702632
# 119                            48                 7.697368
#
#      W22.ScalarWindSpeedDeviation  W22.ScalarMeanWindDirection  \
# 0                        0.986940                    42.496327
# 1                        1.000045                    42.311610
# 2                        1.027139                    42.152913
# 3                        1.070587                    41.626817
# 4                        0.996948                    41.207986
# ..                            ...                          ...
# 115                      0.677339                    44.739281
# 116                      0.677339                    44.739281
# 117                      0.706171                    44.844736
# 118                      0.704305                    44.923497
# 119                      0.708032                    45.028762
#
#      W22.ScalarWindDirectionDeviation  W22.LastWindSpeed  \
# 0                            6.344822                7.5
# 1                            6.212914                6.7
# 2                            6.245114                6.1
# 3                            5.860641                6.2
# 4                            5.333008                7.7
# ..                                ...                ...
# 115                          4.091417                9.5
# 116                          4.091417                9.5
# 117                          4.096976                8.5
# 118                          4.206698                7.4
# 119                          4.308928                7.1
#
#      W22.LastWindDirection  W22.OkPct  \
# 0                       38       95.0
# 1                       45       95.0
# 2                       38       95.0
# 3                       41       95.0
# 4                       44       95.0
# ..                     ...        ...
# 115                     42       95.0
# 116                     42       95.0
# 117                     48       95.0
# 118                     50       95.0
# 119                     51       95.0
#
#                                            source_file
# 0    /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 1    /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 2    /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 3    /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 4    /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# ..                                                 ...
# 115  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 116  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 117  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 118  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 119  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
#
# [120 rows x 31 columns]

# %%
N_arrivals = 100

arrival_data = import_flight_data(data_dir=data_dir,
    limit=N_arrivals, add_source_file=True, usecols=['month', 'day', 'year', 'hour', 'minute', 'second', 'vert_acc', 'radio_altitude'])


full_wind_data = []
idx = 0

for flight_id, flight_df in arrival_data.groupby('source_file'):
    idx +=1
    print(f"Processing flight: {idx}/{len(arrival_data.groupby('source_file'))}")
    try:
        wind_df = extract_wind_data(flight_df)
        wind_df['source_file'] = flight_id
        full_wind_data.append(wind_df)

    except ValueError as e:
        print(f"Error processing flight {flight_id}: {e}")
full_wind_data = pd.concat(full_wind_data, ignore_index=True)
# Out:
# Processing flight: 1/92
# Processing flight: 2/92
# Processing flight: 3/92
# Processing flight: 4/92
# Processing flight: 5/92
# Processing flight: 6/92
# Processing flight: 7/92
# Processing flight: 8/92
# Processing flight: 9/92
# Processing flight: 10/92
# Processing flight: 11/92
# Processing flight: 12/92
# Processing flight: 13/92
# Processing flight: 14/92
# Processing flight: 15/92
# Processing flight: 16/92
# Processing flight: 17/92
# Processing flight: 18/92
# Processing flight: 19/92
# Processing flight: 20/92
# Processing flight: 21/92
# Processing flight: 22/92
# Processing flight: 23/92
# Processing flight: 24/92
# Processing flight: 25/92
# Processing flight: 26/92
# Processing flight: 27/92
# Processing flight: 28/92
# Processing flight: 29/92
# Processing flight: 30/92
# Processing flight: 31/92
# Processing flight: 32/92
# Processing flight: 33/92
# Processing flight: 34/92
# Processing flight: 35/92
# Processing flight: 36/92
# Processing flight: 37/92
# Processing flight: 38/92
# Processing flight: 39/92
# Processing flight: 40/92
# Processing flight: 41/92
# Processing flight: 42/92
# Processing flight: 43/92
# Processing flight: 44/92
# Processing flight: 45/92
# Processing flight: 46/92
# Processing flight: 47/92
# Processing flight: 48/92
# Processing flight: 49/92
# Processing flight: 50/92
# Processing flight: 51/92
# Processing flight: 52/92
# Processing flight: 53/92
# Processing flight: 54/92
# Processing flight: 55/92
# Processing flight: 56/92
# Processing flight: 57/92
# Processing flight: 58/92
# Processing flight: 59/92
# Processing flight: 60/92
# Processing flight: 61/92
# Processing flight: 62/92
# Processing flight: 63/92
# Processing flight: 64/92
# Processing flight: 65/92
# Processing flight: 66/92
# Processing flight: 67/92
# Processing flight: 68/92
# Processing flight: 69/92
# Processing flight: 70/92
# Processing flight: 71/92
# Processing flight: 72/92
# Processing flight: 73/92
# Processing flight: 74/92
# Processing flight: 75/92
# Processing flight: 76/92
# Processing flight: 77/92
# Processing flight: 78/92
# Processing flight: 79/92
# Processing flight: 80/92
# Processing flight: 81/92
# Processing flight: 82/92
# Processing flight: 83/92
# Processing flight: 84/92
# Processing flight: 85/92
# Processing flight: 86/92
# Processing flight: 87/92
# Processing flight: 88/92
# Processing flight: 89/92
# Processing flight: 90/92
# Processing flight: 91/92
# Processing flight: 92/92

# %%
for idx, file in full_wind_data.groupby('source_file'):
    print(file['DateTime'].min(), file['DateTime'].max(), file['source_file'].iloc[0])
# Out:
# 2024-11-28 12:04:29 2024-11-28 12:14:23 /Users/rasmus/Desktop/Fysik/AppliedML2026/Final_project_data/data/ML_data/NBI/FDM data/Arrivals/Nuuk Arrival_ 207724_OY-GRH_28_11_24_16_12.csv
# 2024-11-28 11:32:50 2024-11-28 11:42:44 /Users/rasmus/Desktop/Fysik/AppliedML2026/Final_project_data/data/ML_data/NBI/FDM data/Arrivals/Nuuk Arrival_ 207725_OY-GRP_28_11_24_43_11.csv
# 2024-11-28 14:29:35 2024-11-28 14:39:29 /Users/rasmus/Desktop/Fysik/AppliedML2026/Final_project_data/data/ML_data/NBI/FDM data/Arrivals/Nuuk Arrival_ 