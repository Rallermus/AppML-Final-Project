# %%
from helper_functions import *
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_dir = '/Users/rasmus/Desktop/Fysik/AppliedML2026/Final_project_data/data/ML_data/NBI/FDM data'

df = import_flight_data(data_dir=data_dir,limit=1, recursive=True)

# %%
df.head()
# Out:
#      year  month   day  hour  minute  second  vert_acc  radio_altitude  \
# 0  2024.0   11.0  28.0  12.0    14.0    26.0      1.06          1483.7
# 1  2024.0   11.0  28.0  12.0    14.0    27.0      0.98          1463.0
# 2  2024.0   11.0  28.0  12.0    14.0    28.0      0.94          1432.5
# 3  2024.0   11.0  28.0  12.0    14.0    29.0      1.05          1406.9
# 4  2024.0   11.0  28.0  12.0    14.0    30.0      1.02          1389.8
#
#                                          source_file
# 0  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 1  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 2  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 3  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...
# 4  /Users/rasmus/Desktop/Fysik/AppliedML2026/Fina...

# %%
N_arrivals_tot = 3140

full_arrival_data = import_flight_data(data_dir=data_dir, limit=N_arrivals_tot, recursive=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 3
#       1 N_arrivals_tot = 3140
#       2
# ----> 3 full_arrival_data = import_flight_data(data_dir=data_dir, limit=N_arrivals_tot, recursive=True)
#
# File ~/Desktop/Fysik/AppliedML2026/AppMLFinalProject/Rasmus/helper_functions.py:93, in import_flight_data(data_dir, pattern, recursive, start, limit, add_source_file, **read_csv_kwargs)
#      91 if 'GKN' in csv_path.name: #Skip files with OY-GKN, as their format sucks
#      92     continue
# ---> 93 frame = pd.read_csv(csv_path, low_memory=False)
#      95 frame.columns = [COLUMN_MAP.get(c, c) for c in frame.columns]
#      96 needed = [
#      97     'year','month','day',
#      98     'hour','minute','second',
#      99     'vert_acc','radio_altitude']
#
# File ~/Desktop/Fysik/AppliedML2026/AML2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/Fysik/AppliedML2026/AML2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/Desktop/Fysik/AppliedML2026/AML2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/Desktop/Fysik/AppliedML2026/AML2/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:239, in CParserWrapper.read(self, nrows)
#     236         data = _concatenate_chunks(chunks)
#     238     else:
# --> 239         data = self._reader.read(nrows)
#     240 except StopIteration:
#     241     if self._first_chunk:
#
# File parsers.pyx:820, in pandas._libs.parsers.TextReader.read()
# --> 820 'Could not get source, probably due dynamically evaluated source code.'
#
# File parsers.pyx:921, in pandas._libs.parsers.TextReader._read_rows()
# --> 921 'Could not get source, probably due dynamically evaluated source code.'
#
# File parsers.pyx:1083, in pandas._libs.parsers.TextReader._convert_column_data()
# -> 1083 'Could not get source, probably due dynamically evaluated source code.'
#
# File parsers.pyx:1456, in pandas._libs.parsers._maybe_upcast()
# -> 1456 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Desktop/Fysik/AppliedML2026/AML2/lib/python3.11/site-packages/numpy/core/multiarray.py:1131, in putmask(a, mask, values)
#    1082     """
#    1083     copyto(dst, src, casting='same_kind', where=True)
#    1084
#    (...)   1126
#    1127     """
#    1128     return (dst, src, where)
# -> 1131 @array_function_from_c_func_and_dispatcher(_multiarray_umath.putmask)
#    1132 def putmask(a, /, mask, values):
#    1133     """
#    1134     putmask(a, mask, values)
#    1135
#    (...)   1171
#    1172     """
#    1173     return (a, mask, values)
#
# KeyboardInterrupt:

# %%
full_arrival_data["g_deviation"] = (full_arrival_data["vert_acc"] - 1).abs()

# %%
y_df = full_arrival_data.groupby('source_file').agg(year=('year', 'first'), month=('month', 'first'), day=('day', 'first'), hour=('hour', 'first'), 
                                                    minute=('minute', 'first'), second=('second', 'first'), max_vert_acc = ('g_deviation', 'max'), source_file=('source_file', 'first'))

# %%
y_df.head()
from pathlib import Path

output_path = Path.cwd().parent / "y_data.csv"
y_df.to_csv(output_path, index=False)

# %%
wind_data = pd.read_csv('/Users/rasmus/Desktop/Fysik/AppliedML2026/AppMLFinalProject/All_wind_data.csv')

# %%
wind_files = wind_data['source_file'].unique()
y_files = y_df['source_file'].unique()
shared_files = np.intersect1d(wind_files, y_files)

y_df_shared = y_df[y_df['source_file'].isin(shared_files)]

y_df_shared.to_csv(output_path, index=False)
